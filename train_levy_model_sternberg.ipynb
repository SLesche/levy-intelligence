# %%
# %run setup_levy_model_sternberg.py
# Out:
# 2024-06-10 12:35:44.074259: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-10 12:35:44.075649: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-10 12:35:44.095920: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-10 12:35:44.095942: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-10 12:35:44.096461: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-10 12:35:44.099797: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-10 12:35:44.100392: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-10 12:35:44.612817: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-06-10 12:35:44.839785: I itex/core/wrapper/itex_cpu_wrapper.cc:70] Intel Extension for Tensorflow* AVX2 CPU backend is loaded.
# 2024-06-10 12:35:44.897365: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-10 12:35:44.897562: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /home/slesche/.local/lib/python3.10/site-packages/bayesflow/trainers.py:27: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# INFO:root:Performing 2 pilot runs with the lfm model...
# INFO:root:Shape of parameter batch after 2 pilot simulations: (batch_size = 2, 5)
# INFO:root:Shape of simulation batch after 2 pilot simulations: (batch_size = 2, 100, 2)
# INFO:root:No optional prior non-batchable context provided.
# INFO:root:No optional prior batchable context provided.
# INFO:root:No optional simulation non-batchable context provided.
# INFO:root:No optional simulation batchable context provided.
# 2.15.1
# INFO:root:Initialized empty loss history.
# INFO:root:Initialized networks from scratch.
# INFO:root:Performing a consistency check with provided components...
# [[1.1 3.  0.3 0.2 1.5]] [[0.6 3.  0.2 0.2 0.3]]
# INFO:root:Done.

# %%
f = open("training_data_sternberg.obj","rb")
train_data  = pickle.load(f)
f.close()

# %%
history = trainer.train_offline(
    simulations_dict = train_data, 
    epochs = 100, 
    batch_size = 16
)
# Out:
# Training epoch 1:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 2:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 3:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 4:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 5:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 6:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 7:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 8:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 9:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 10:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 11:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 12:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 13:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 14:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 15:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 16:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 17:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 18:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 19:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 20:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 21:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 22:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 23:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 24:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 25:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 26:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 27:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 28:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 29:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 30:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 31:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 32:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 33:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 34:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 35:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 36:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 37:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 38:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 39:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 40:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 41:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 42:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 43:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 44:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 45:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 46:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 47:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 48:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 49:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 50:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 51:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 52:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 53:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 54:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 55:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 56:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 57:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 58:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 59:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 60:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 61:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 62:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 63:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 64:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 65:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 66:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 67:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 68:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 69:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 70:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 71:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 72:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 73:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 74:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 75:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 76:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 77:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 78:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 79:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 80:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 81:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 82:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 83:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 84:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 85:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 86:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 87:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 88:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 89:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 90:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 91:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 92:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 93:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 94:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 95:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 96:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 97:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 98:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 99:   0%|          | 0/6250 [00:00<?, ?it/s]
# Training epoch 100:   0%|          | 0/6250 [00:00<?, ?it/s]
# /home/slesche/.local/lib/python3.10/site-packages/bayesflow/helper_classes.py:683: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   losses_list = pd.concat(losses_list, axis=0).value.to_list()

# %%
history = trainer.load_pretrained_network()

# %%
# Generate some validation data
validation_sims = configurator(model(batch_size=1000))

# Extract unstandardized prior draws and transform to original scale
prior_samples = validation_sims["parameters"]

print(
    f"Estimation will be performed on data sets with {validation_sims['summary_conditions'].shape[1]} simulated trials."
)
# Out:
# Estimation will be performed on data sets with 100 simulated trials.

# %%
# Generate 100 posterior draws for each of the 1000 simulated data sets
post_samples = amortizer.sample(validation_sims, n_samples=100)

# Unstandardize posterior draws into original scale
post_samples = post_samples

# %%
f = bf.diagnostics.plot_sbc_histograms(post_samples, prior_samples, num_bins=10, param_names=PARAM_NAMES)
# Out:
# INFO:root:The ratio of simulations / posterior draws should be > 20 for reliable variance reduction, but your ratio is 10.                    Confidence intervals might be unreliable!

# %%
f = bf.diagnostics.plot_sbc_ecdf(post_samples, prior_samples, stacked=False, difference=True, param_names=PARAM_NAMES)

# %%
post_samples = amortizer.sample(validation_sims, n_samples=1000)

# %%
f = bf.diagnostics.plot_recovery(
    post_samples, prior_samples, param_names=prior.param_names, point_agg=np.mean, uncertainty_agg=np.std
)

# %%
f = bf.diagnostics.plot_z_score_contraction(post_samples, prior_samples, param_names=prior.param_names)
